# %%
from bs4 import BeautifulSoup
import urllib.request as req

# %%
url = "http://sports.news.naver.com/index.nhn"

res = req.urlopen(url)

soup = BeautifulSoup(res, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="스포츠홈 : 네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <title>스포츠홈 : 네이버 스포츠</title>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2017/12/14/170701/css/generated/nsportsCss.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2017/12/14/170701/css/generated/nsportsHome.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.naver.com/favicon.ico?v=20140228" rel="shortcut icon" type="image/x-icon"/>
# <!-- script -->
# ...

# %%
print(soup)
#mostCommentedNewsList > li.best > a > span

title = soup.find("span.title")
print(type(title))
#for i in title:
 #   name  = i.string
  #  print(name)

# %%
title = soup.find_all('li',{'class':'best'})

# %%
for text in title:
    print(text.get_text())
# Out:
# 1[단독인터뷰] ‘이제는 kt맨’ 황재균 “탈꼴찌? 기대하셔도 좋다”
#
#
#
#
# 1[박문성] 간결해진 손흥민
#
#
#
#
#
# 1
#
#
#
#
#
#  '멋진 헤더골' 4경기 연속골에 성공하는 손흥민
#
# 재생시간01:24
# 재생수1,269,348

# %%
[text.get_text() for text in title]
# Out:
# ['\n\n1[단독인터뷰] ‘이제는 kt맨’ 황재균 “탈꼴찌? 기대하셔도 좋다”\n\n',
#  '\n\n1[박문성] 간결해진 손흥민\n\n',
#  "\n\n\n1\n\n\n\n\n\n '멋진 헤더골' 4경기 연속골에 성공하는 손흥민\n\n재생시간01:24\n재생수1,269,348\n\n\n\n"]

# %%
len(text)
# Out:
# 3

# %%
print(title)
# Out:
# [<li class="best">
# <a data-not-edited="Y" href="/kbaseball/news/read.nhn?oid=382&amp;aid=0000613517" onclick="clickcr(this, 'rnk*r.list', '382_0000613517', '1', event);" title="[단독인터뷰] ‘이제는 kt맨’ 황재균 “탈꼴찌? 기대하셔도 좋다”">
# <span class="title"><span class="rank_num">1</span>[단독인터뷰] ‘이제는 kt맨’ 황재균 “탈꼴찌? 기대하셔도 좋다”</span>
# </a>
# </li>, <li class="best">
# <a data-not-edited="Y" href="/wfootball/news/read.nhn?oid=208&amp;aid=0000001252" onclick="clickcr(this, 'rnk*p.list', '208_0000001252', '1', event);" title="[박문성] 간결해진 손흥민">
# <span class="title"><span class="rank_num">1</span>[박문성] 간결해진 손흥민</span>
# </a>
# </li>, <li class="best">
# <a href="/video.nhn?id=378271" onclick="clickcr(this, 'rnk*m.list', '378271', '1', event); " title=" '멋진 헤더골' 4경기 연속골에 성공하는 손흥민">
# <div class="thmb">
# <b class="rank_num">1</b>
# <span class="mask"></span>
# <!-- [D] 이미지 alt값은 비워주세요 -->
# ...

# %%
len(title)
# Out:
# 3
